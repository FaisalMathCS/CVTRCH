# %%
import torch

# %%
x = torch.tensor([[1, 2]])
y = torch.tensor([[1], [2]])

# %%
print(type(x))
print(type(y))
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %%
print(x.shape)
print(y.shape)
# Out:
# torch.Size([1, 2])
# torch.Size([2, 1])

# %%
zeroes = torch.zeros((3, 4))
ones = torch.ones((3, 4))
